# %% [markdown]
# # Load the data set

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/training.csv")

# %%
print(df.shape)
# Out:
# (640840, 10)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'store_ID', 'day_of_week', 'date', 'nb_customers_on_day',
#        'open', 'promotion', 'state_holiday', 'school_holiday', 'sales'],
#       dtype='str')

# %%
print(df.dtypes)
# Out:
# Unnamed: 0             int64
# store_ID               int64
# day_of_week            int64
# date                     str
# nb_customers_on_day    int64
# open                   int64
# promotion              int64
# state_holiday            str
# school_holiday         int64
# sales                  int64
# dtype: object

# %%
print(df.isna())
# Out:
#         Unnamed: 0  store_ID  day_of_week   date  nb_customers_on_day   open  \
# 0            False     False        False  False                False  False
# 1            False     False        False  False                False  False
# 2            False     False        False  False                False  False
# 3            False     False        False  False                False  False
# 4            False     False        False  False                False  False
# ...            ...       ...          ...    ...                  ...    ...
# 640835       False     False        False  False                False  False
# 640836       False     False        False  False                False  False
# 640837       False     False        False  False                False  False
# 640838       False     False        False  False                False  False
# 640839       False     False        False  False                False  False
#
#         promotion  state_holiday  school_holiday  sales
# 0           False          False           False  False
# 1           False          False           False  False
# 2           False          False           False  False
# 3           False          False           False  False
# 4           False          False           False  False
# ...           ...            ...             ...    ...
# 640835      False          False           False  False
# 640836      False          False           False  False
# 640837      False          False           False  False
# 640838      False          False           False  False
# 640839      False          False           False  False
#
# [640840 rows x 10 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  store_ID  day_of_week        date  nb_customers_on_day  open  \
# 0      425390       366            4  2013-04-18                  517     1
# 1      291687       394            6  2015-04-11                  694     1
# 2      411278       807            4  2013-08-29                  970     1
# 3      664714       802            2  2013-05-28                  473     1
# 4      540835       726            4  2013-10-10                 1068     1
#
#    promotion state_holiday  school_holiday  sales
# 0          0             0               0   4422
# 1          0             0               0   8297
# 2          1             0               0   9729
# 3          1             0               0   6513
# 4          1             0               0  10882

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0             0
# store_ID               0
# day_of_week            0
# date                   0
# nb_customers_on_day    0
# open                   0
# promotion              0
# state_holiday          0
# school_holiday         0
# sales                  0
# dtype: int64

# %%
print("state holiday:", df["state_holiday"].unique())
print("number of customers per day:", df["nb_customers_on_day"].unique())
print("open:", df["open"].unique())
# Out:
# state holiday: <StringArray>
# ['0', 'a', 'c', 'b']
# Length: 4, dtype: str
# number of customers per day: [ 517  694  970 ... 4630 3713 4003]
# open: [1 0]

# %%
df[df["sales"] == 0]
# Out:
#         Unnamed: 0  store_ID  day_of_week        date  nb_customers_on_day  \
# 6           600327       659            7  2014-06-08                    0
# 10          561067       273            7  2014-10-05                    0
# 18          409022       767            7  2013-01-27                    0
# 34          605423       534            7  2014-06-08                    0
# 35          231682       514            7  2014-03-09                    0
# ...            ...       ...          ...         ...                  ...
# 640807      381567       167            7  2014-07-27                    0
# 640812       49811       870            3  2014-07-23                    0
# 640814      556209       650            7  2014-03-23                    0
# 640834      304137       329            7  2013-09-15                    0
# 640839      305711       695            7  2015-05-03                    0
#
#         open  promotion state_holiday  school_holiday  sales
# 6          0          0             0               0      0
# 10         0          0             0               0      0
# 18         0          0             0               0      0
# 34         0          0             0               0      0
# 35         0          0             0               0      0
# ...      ...        ...           ...             ...    ...
# 640807     0          0             0               0      0
# 640812     0          0             0               1      0
# 640814     0          0             0               0      0
# 640834     0          0             0               0      0
# 640839     0          0             0               0      0
#
# [108855 rows x 10 columns]

# %%
df[df["nb_customers_on_day"] == 0]
# Out:
#         Unnamed: 0  store_ID  day_of_week        date  nb_customers_on_day  \
# 6           600327       659            7  2014-06-08                    0
# 10          561067       273            7  2014-10-05                    0
# 18          409022       767            7  2013-01-27                    0
# 34          605423       534            7  2014-06-08                    0
# 35          231682       514            7  2014-03-09                    0
# ...            ...       ...          ...         ...                  ...
# 640807      381567       167            7  2014-07-27                    0
# 640812       49811       870            3  2014-07-23                    0
# 640814      556209       650            7  2014-03-23                    0
# 640834      304137       329            7  2013-09-15                    0
# 640839      305711       695            7  2015-05-03                    0
#
#         open  promotion state_holiday  school_holiday  sales
# 6          0          0             0               0      0
# 10         0          0             0               0      0
# 18         0          0             0               0      0
# 34         0          0             0               0      0
# 35         0          0             0               0      0
# ...      ...        ...           ...             ...    ...
# 640807     0          0             0               0      0
# 640812     0          0             0               1      0
# 640814     0          0             0               0      0
# 640834     0          0             0               0      0
# 640839     0          0             0               0      0
#
# [108854 rows x 10 columns]

# %% [markdown]
# # Find the anomalous row

# %%
anomaly = df[(df['sales'] == 0) & (df['nb_customers_on_day'] > 0)]
print(anomaly)
# Out:
#         Unnamed: 0  store_ID  day_of_week        date  nb_customers_on_day  \
# 352744      319242       948            4  2013-04-25                    5
#
#         open  promotion state_holiday  school_holiday  sales
# 352744     1          1             0               0      0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Drop the row identifier

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
print('Dropped row-ID column. New shape:', df.shape)
# Out:
# Dropped row-ID column. New shape: (640840, 9)

# %% [markdown]
# ### Fix `date` data types , extract useful features, drop the original `date` column

# %%
df["date"] = pd.to_datetime(df["date"])
print(df["date"].dtype)

df['year']        = df['date'].dt.year
df['month']       = df['date'].dt.month
df['day']         = df['date'].dt.day
df['week']        = df['date'].dt.isocalendar().week.astype(int)
df['is_weekend']  = df['date'].dt.dayofweek.isin([5, 6]).astype(int)
df = df.drop(columns=['date'])

print(df.head())
# Out:
# datetime64[us]
#    store_ID  day_of_week  nb_customers_on_day  open  promotion state_holiday  \
# 0       366            4                  517     1          0             0
# 1       394            6                  694     1          0             0
# 2       807            4                  970     1          1             0
# 3       802            2                  473     1          1             0
# 4       726            4                 1068     1          1             0
#
#    school_holiday  sales  year  month  day  week  is_weekend
# 0               0   4422  2013      4   18    16           0
# 1               0   8297  2015      4   11    15           1
# 2               0   9729  2013      8   29    35           0
# 3               0   6513  2013      5   28    22           0
# 4               0  10882  2013     10   10    41           0

# %% [markdown]
# ### for column `state_holiday ` Creates a binary column for each category, drops holiday_0 to avoid the dummy variable trap (multicollinearity),

# %%
df = pd.get_dummies(df, columns=['state_holiday'], prefix='holiday', drop_first=True)
print(df.head())
# Out:
#    store_ID  day_of_week  nb_customers_on_day  open  promotion  \
# 0       366            4                  517     1          0
# 1       394            6                  694     1          0
# 2       807            4                  970     1          1
# 3       802            2                  473     1          1
# 4       726            4                 1068     1          1
#
#    school_holiday  sales  year  month  day  week  is_weekend  holiday_a  \
# 0               0   4422  2013      4   18    16           0      False
# 1               0   8297  2015      4   11    15           1      False
# 2               0   9729  2013      8   29    35           0      False
# 3               0   6513  2013      5   28    22           0      False
# 4               0  10882  2013     10   10    41           0      False
#
#    holiday_b  holiday_c
# 0      False      False
# 1      False      False
# 2      False      False
# 3      False      False
# 4      False      False

# %%
df[(df["open"] == 0) & (df["sales"] > 0)]
# Out:
# Empty DataFrame
# Columns: [store_ID, day_of_week, nb_customers_on_day, open, promotion, school_holiday, sales, year, month, day, week, is_weekend, holiday_a, holiday_b, holiday_c]
# Index: []

# %%
df[(df["open"] == 1) & (df["sales"] == 0)]
# Out:
#         store_ID  day_of_week  nb_customers_on_day  open  promotion  \
# 54379        339            3                    0     1          0
# 61554       1039            3                    0     1          0
# 63404        983            5                    0     1          0
# 82644        387            4                    0     1          0
# 117219       762            4                    0     1          0
# 137903       303            4                    0     1          0
# 163742        25            3                    0     1          0
# 180912       835            4                    0     1          0
# 188539       835            3                    0     1          0
# 209801       548            5                    0     1          1
# 235104       623            6                    0     1          0
# 238863      1017            3                    0     1          1
# 261324       238            4                    0     1          0
# 266033      1100            3                    0     1          1
# 267171       983            6                    0     1          0
# 280585       364            2                    0     1          0
# 283951       661            5                    0     1          1
# 303685       708            3                    0     1          1
# 331739       232            4                    0     1          1
# 352744       948            4                    5     1          1
# 390198       699            4                    0     1          1
# 410884       102            6                    0     1          0
# 413385       887            3                    0     1          0
# 431276        25            4                    0     1          0
# 443643       850            6                    0     1          0
# 447091       353            6                    0     1          0
# 571983      1039            2                    0     1          0
# 590298       971            5                    0     1          0
# 621724       259            4                    0     1          1
# 627892       357            1                    0     1          0
# 629225       327            3                    0     1          0
#
#         school_holiday  sales  year  month  day  week  is_weekend  holiday_a  \
# 54379                0      0  2013      1   30     5           0      False
# 61554                0      0  2013      7   10    28           0      False
# 63404                0      0  2014      1   17     3           0      False
# 82644                1      0  2014      7   24    30           0      False
# 117219               0      0  2013      1   17     3           0      False
# 137903               1      0  2014      7   24    30           0      False
# 163742               0      0  2014      2   12     7           0      False
# 180912               0      0  2014      9   11    37           0      False
# 188539               0      0  2014      9   10    37           0      False
# 209801               1      0  2014      9    5    36           0      False
# 235104               0      0  2014      1   25     4           1      False
# 238863               0      0  2014      6    4    23           0      False
# 261324               1      0  2014      7   24    30           0      False
# 266033               0      0  2014      4   30    18           0      False
# 267171               0      0  2014      1   18     3           1      False
# 280585               0      0  2013      5    7    19           0      False
# 283951               0      0  2014      4    4    14           0      False
# 303685               0      0  2014     10    1    40           0      False
# 331739               0      0  2013      1   24     4           0      False
# 352744               0      0  2013      4   25    17           0      False
# 390198               0      0  2015      2    5     6           0      False
# 410884               0      0  2014      7   12    28           1      False
# 413385               0      0  2014      7   23    30           0      False
# 431276               0      0  2014      2   13     7           0      False
# 443643               0      0  2014      3   29    13           1      False
# 447091               0      0  2013      3   16    11           1      False
# 571983               0      0  2013      7    9    28           0      False
# 590298               1      0  2015      5   15    20           0      False
# 621724               0      0  2013      2    7     6           0      False
# 627892               0      0  2014      9   22    39           0      False
# 629225               0      0  2014      3   12    11           0      False
#
#         holiday_b  holiday_c
# 54379       False      False
# 61554       False      False
# 63404       False      False
# 82644       False      False
# 117219      False      False
# 137903      False      False
# 163742      False      False
# 180912      False      False
# 188539      False      False
# 209801      False      False
# 235104      False      False
# 238863      False      False
# 261324      False      False
# 266033      False      False
# 267171      False      False
# 280585      False      False
# 283951      False      False
# 303685      False      False
# 331739      False      False
# 352744      False      False
# 390198      False      False
# 410884      False      False
# 413385      False      False
# 431276      False      False
# 443643      False      False
# 447091      False      False
# 571983      False      False
# 590298      False      False
# 621724      False      False
# 627892      False      False
# 629225      False      False

# %%
df = df[df["open"] == 1]
print(df.shape)
# Out:
# (640840, 15)

# %%
open_with_customers =  df[(df['open'] == 1) & (df['nb_customers_on_day'] > 0)]
total = len(open_with_customers)
anomalies = len(open_with_customers[open_with_customers['sales'] == 0])
pct = (anomalies / total) * 100
print(f'Total open days with customers: {total}')
print(f'Days with sales = 0:            {anomalies}')
print(f'Anomaly percentage:             {pct:.4f}%')
print(df.shape)
# Out:
# Total open days with customers: 531986
# Days with sales = 0:            1
# Anomaly percentage:             0.0002%
# (640840, 15)
